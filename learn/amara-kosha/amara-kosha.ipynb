# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'Lohit Devanagari'
plt.rcParams['font.family'] = 'Arial Unicode MS'

def clean_data(df):
    # Drop duplicate rows across all columns
    df = df.drop_duplicates()
    # Drop rows with missing data across all columns
    df = df.dropna()
    return df

# Loaded variable 'df' from URI: /Users/sunder/projects/cahc/cahc-utils/datasets/amara-kosha-list.csv
df = pd.read_csv(r'/Users/sunder/projects/cahc/cahc-utils/datasets/amara-kosha-list.csv')

df_clean = clean_data(df.copy())
df_clean.head()
# Out:
#        padam  kaanda  varga  shloka  paada  cnt linga
# 0      स्वर्       1      1       6      1    1  अव्य
# 1     स्वर्ग       1      1       6      1    2   पुं
# 2        नाक       1      1       6      1    3   पुं
# 3    त्रिदिव       1      1       6      1    4   पुं
# 4  त्रिदशालय       1      1       6      1    5   पुं

# %%
pd.DataFrame(df_clean.linga.value_counts())
# Out:
#              count
# linga
# पुं           4617
# स्त्री        2209
# नपुं          1831
# वि            1460
# अव्य           281
# पुं-नपुं       247
# स्त्री-पुं      61
# पुं-द्वि        16
# स्त्री-नपुं     13
# पुं-बहु         11
# स्त्री-बहु       6
# नपुं-अव्य        2
# स्त्री-द्वि      2

# %%
# top 10 most frequent padam
pd.DataFrame(df_clean.padam.value_counts().head(50))
# Out:
#          count
# padam
# घन           7
# अरिष्ट       7
# शुचि         6
# ध्रुव        6
# लता          6
# वृष          6
# फल           6
# बल           6
# काम          6
# शङ्ख         5
# कटु          5
# प्लव         5
# अक्ष         5
# वर           5
# गन्धर्व      5
# पुष्कर       5
# बाल          5
# वसु          5
# पक्ष         5
# अनन्ता       5
# शुक्र        5
# पण           5
# अमृत         5
# सुवहा        5
# शिवा         5
# तिलक         5
# क्षय         5
# वृद्धि       4
# गोप          4
# रस           4
# प्राण        4
# केसर         4
# सित          4
# रक्त         4
# विषय         4
# कारवी        4
# हैमवती       4
# वृत्त        4
# शीत          4
# गो           4
# कृष्ण        4
# स्व          4
# गुण          4
# दण्ड         4
# शिखा         4
# प्रियक       4
# अस्र         4
# चक्र         4
# श्यामा       4
# गणिका        4

# %%
#Create a word cloud of the top 50 most frequent padam in the Amarakosha df
from wordcloud import WordCloud
wordcloud = WordCloud(font_path='/Library/Fonts/Arial Unicode.ttf',  ).generate(' '.join(df_clean.head(1).padam), )
# wordcloud = WordCloud(font_path='/Library/Fonts/Arial Unicode.ttf').generate( 
#     "Some text here that is long enough to be displayed in the word cloud text text text. "
#     )
# displaty the word cloud
plt.figure(figsize=(10, 10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# Out:
# 'स्वर् स्वर्ग नाक त्रिदिव त्रिदशालय सुरलोक द्यो दिव् त्रिविष्टप अमर'

# %%
# histogram of top 100 padam frequency with utf-8 encoding
# df_clean.padam.value_counts().head(50).plot(kind='bar', figsize=(20,10), fontsize=20)

# %%
# histogram of values of histogram of padam frequency
df_clean.padam.value_counts().value_counts()#.plot(kind='bar', figsize=(20,10), fontsize=20)
# Out:
# count
# 1    7730
# 2     996
# 3     220
# 4      57
# 5      18
# 6       7
# 7       2
# Name: count, dtype: int64

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from indicnlp.tokenize import indic_tokenize  

# Your Devanagari text
text = " यह एक उदाहरण हैराति "*100

# Generate a word cloud image
wordcloud = WordCloud(
    font_path='/Library/Fonts/Arial Unicode.ttf', 
    width=800, height=400, background_color='white').generate(text)

# Display the generated image
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/yw/khs2fgqs5d39_5lgfvh8mqlh0000gn/T/ipykernel_50306/4181314331.py in <module>
#       1 from wordcloud import WordCloud
#       2 import matplotlib.pyplot as plt
# ----> 3 from indicnlp.tokenize import indic_tokenize
#       4
#       5 # Your Devanagari text
#
# ModuleNotFoundError: No module named 'indicnlp'

# %%
import matplotlib.pyplot as plt

plt.rcParams['font.family'] = 'Arial Unicode MS'
# plt.rcParams['font.family'] = 'Monospace'
# plt.rcParams['font.family'] = 'Lohit Devanagari'

plt.title('Devanagari: नमस्ते, राजा , रानी, रानि, Latin: Hello')
plt.show()
